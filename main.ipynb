# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.6/911.6 kB 33.2 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/112.6 GB disk)

# %%
from ultralytics import YOLO
model = YOLO('yolov8s-seg.pt')
# Out:
# ...
# 100%|██████████| 22.8M/22.8M [00:00<00:00, 43.2MB/s]

# %%
results = model.train(
    data='/content/drive/MyDrive/image_segmentation/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='yolov8-seg-exp'
)
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
os.listdir()
# Out:
# ['dataset',
#  'data.yaml',
#  'main.ipynb',
#  'segment',
#  'yolo11n.pt',
#  'yolov8s-seg.pt']

# %%
os.chdir('/content/drive/MyDrive/image_segmentation/segment/yolov8-seg-exp')

# %%
from IPython.display import Image, display

confusion_matrix = 'confusion_matrix.png'
display(Image(image_path))

# %%
results = 'results.png'
display(Image(results))

# %%
my_model = YOLO('/content/drive/MyDrive/image_segmentation/segment/yolov8-seg-exp/weights/best.pt')

# %%
results = my_model('/content/drive/MyDrive/image_segmentation/vr.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/image_segmentation/vr.jpg: 448x640 1 vrheadset, 116.2ms
# Speed: 3.1ms preprocess, 116.2ms inference, 6.3ms postprocess per image at shape (1, 3, 448, 640)

# %%
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
test2 = my_model('/content/drive/MyDrive/image_segmentation/man-wearing-virtual-reality-headset-and-playing-game-on-isolated-transparent-background-free-png.webp')
# Out:
# image 1/1 /content/drive/MyDrive/image_segmentation/man-wearing-virtual-reality-headset-and-playing-game-on-isolated-transparent-background-free-png.webp: 448x640 1 gamepad, 1 vrheadset, 24.4ms
# Speed: 3.9ms preprocess, 24.4ms inference, 3.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
test2[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=1470x980>

# %%
test3 = my_model('/content/drive/MyDrive/image_segmentation/test3.webp')
# Out:
# image 1/1 /content/drive/MyDrive/image_segmentation/test3.webp: 480x640 1 gamepad, 1 vrheadset, 82.2ms
# Speed: 3.4ms preprocess, 82.2ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)

# %%
test3[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=390x280>
